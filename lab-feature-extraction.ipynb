# %% [markdown]
# # Lab | Feature extraction
#
#
# For this lab, we will be using the same dataset we used in the previous labs. We recommend using the same notebook since you will be reusing the same variables you previous created and used in labs.

# %% [markdown]
# ## Instructions
#
#
# 1. Open the categorical dataframe we created before.
# 2. Plot all the categorical variables with the proper plot. What can you see?
# 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them? Make any changes you feel are necessary.
# 5. Plot time variable. Can you extract something from it?
# 6. The time variable can be useful. You shoud transform its data into a more useful form. Hint: Day, week, and month as integers might be useful.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categorical_df = pd.read_csv('categorical.csv')
categorical_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1         Nevada       No   Premium  Bachelor         Employed      F
# 2     California       No     Basic  Bachelor       Unemployed      M
# 3     Washington       No     Basic  Bachelor         Employed      M
# 4         Oregon      Yes     Basic  Bachelor         Employed      F
# ...          ...      ...       ...       ...              ...    ...
# 7784  California       No   Premium   College         Employed      F
# 7785  California      Yes  Extended   College         Employed      F
# 7786  California       No  Extended  Bachelor       Unemployed      M
# 7787  California       No  Extended   College         Employed      M
# 7788  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type policy renew_offer_type  \
# 0         Suburban        Married  Corporate Auto     L3           Offer1
# 1         Suburban        Married   Personal Auto     L3           Offer1
# 2         Suburban        Married  Corporate Auto     L2           Offer1
# 3            Rural         Single   Personal Auto     L1           Offer1
# 4            Rural        Married   Personal Auto     L3           Offer2
# ...            ...            ...             ...    ...              ...
# 7784      Suburban         Single   Personal Auto     L2           Offer1
# 7785      Suburban       Divorced  Corporate Auto     L3           Offer1
# 7786      Suburban         Single  Corporate Auto     L2           Offer1
# 7787      Suburban        Married   Personal Auto     L2           Offer3
# 7788      Suburban         Single  Corporate Auto     L3           Offer4
#
#      sales_channel  vehicle_class vehicle_size
# 0            Agent   Two-Door Car      Medsize
# 1            Agent   Two-Door Car      Medsize
# 2      Call Center            SUV      Medsize
# 3            Agent  Four-Door Car      Medsize
# 4              Web   Two-Door Car      Medsize
# ...            ...            ...          ...
# 7784        Branch  Four-Door Car        Large
# 7785        Branch  Four-Door Car      Medsize
# 7786        Branch  Four-Door Car      Medsize
# 7787        Branch  Four-Door Car        Large
# 7788   Call Center   Two-Door Car      Medsize
#
# [7789 rows x 14 columns]

# %%
for column in categorical_df.columns:
    print(f" {column}: {categorical_df[column].unique()}")
# Out:
#  state: ['Washington' 'Nevada' 'California' 'Oregon' 'Arizona']
#  response: ['No' 'Yes']
#  coverage: ['Basic' 'Premium' 'Extended']
#  education: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
#  employmentstatus: ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
#  gender: ['F' 'M']
#  location_code: ['Suburban' 'Rural' 'Urban']
#  marital_status: ['Married' 'Single' 'Divorced']
#  policy_type: ['Corporate Auto' 'Personal Auto' 'Special Auto']
#  policy: ['L3' 'L2' 'L1']
#  renew_offer_type: ['Offer1' 'Offer2' 'Offer4' 'Offer3']
#  sales_channel: ['Agent' 'Call Center' 'Web' 'Branch']
#  vehicle_class: ['Two-Door Car' 'SUV' 'Four-Door Car' 'Sports Car']
#  vehicle_size: ['Medsize' 'Small' 'Large']

# %%
for column in categorical_df.columns:
    sns.countplot(x=column, data=categorical_df)
    plt.title(f'{column} Distribution')
    plt.xticks(rotation=45)
    plt.show()
